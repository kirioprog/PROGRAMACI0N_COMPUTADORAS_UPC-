# %% [markdown]
# # Hoja de Ejercicios 8

# %% [markdown]
# ### Ejercicio 1
# Complete la definición de una clase llamada Rectángulo que guarde los atributos (base y altura) de un rectángulo e implemente 2 métodos: El primero que retorne el perímetro y el segundo que retorne el área.

# %%
class Rectangulo:
    
    def __init__(self, base, altura):
        self.base = base
        self.altura = altura

    def __repr__(self):
        pass

    
    def perimetro(self):
        pass

    
    def area(self):
        pass



# Codigo de prueba de la clase    
R = Rectangulo(base = 10, altura = 2)
print(R.area())
print(R.perimetro())

# %% [markdown]
# ### Ejercicio 2
# Complete una clase nueva llamada *CircuitoResistivo* que permita definir un objeto resistivo de la forma:
#
#     c1 = CircuitoResistivo([120, 450, 345, 1000, 780, 1300])
#
#     (Una clase que tiene como atributo un grupo de resistencias las cuales estan almacenadas en una lista)
#
# Además debe contener los siguientes métodos:
#
#     calculaEquivalenteSerie:  Para retornar el valor de la resistencia equivalente en serie del circuito
#                               Para ello sumar todos los valores de las resistencias del circuito.
#
#     calculaEquivalenteParalelo:  Para retornar el valor de la resistencia equivalente en paralelo del circuito
#                                  Para ello sumar todas las inversas de los valores de las resistencias del circuito y
#                                  finalmente, calcular la inversa de dicha suma.

# %%
class CircuitoResistivo:
    
    # Inicializacion
    def __init__(self, resistencias=[]):
        pass
        
        
    def calculaEquivalenteSerie(self):
        pass
        

    def calculaEquivalenteParalelo(self):
        pass


# Prueba 
c1 = CircuitoResistivo([120, 450, 345, 1000, 780, 1300])
res = c1.calculaEquivalenteSerie()
rep = c1.calculaEquivalenteParalelo()

# %% [markdown]
# ### Ejercicio 3
#
# Complete la clase llamada Alumno que guarde los atributos (campos) de un alumno de su institución. Los atributos del alumno serían:
#
# - Nombres (por defecto en blanco)
# - Apellidos (por defecto en blanco)
# - Codigo (por defecto en blanco)
# - Modalidad de ingreso (por defecto "Examen")
# - Cursos Matriculados (por defecto 0)
# - Nota Curso 1 (por defecto 0)
# - Nota Curso 2 (por defecto 0)
# - Nota Curso 3 (por defecto 0)
# - Nota Curso 4 (por defecto 0)
# - Nota Curso 5 (por defecto 0)
#
# Se podría por lo tanto crear un alumno de la siguiente forma:
#
#     a1 = Alumno("Francisco", "Riado", 201611090)   # Asumirá los demas atributos por defecto
#
# Cree los siguientes métodos:
#
# - promedio(): Retornará el promedio del número de cursos cursados
# - estaAprobado(): Retornara True o False si esta aprobado en el ciclo
#
# El alumno aprobará el ciclo si de 5 cursos matriculados (por ejemplo), por lo menos ha aprobado en 4 (notas >= 12.5)

# %%
class Alumno(object):
    
    def __init__(self, nombre="", apellido="", codigo="", modalidad="Examen", num_cur=0, n1=0, n2=0, n3=0, n4=0, n5=0):
        pass

    
    def promedio(self):
        pass

    
    def estaAprobado(self):
        pass

    
    def __repr__(self):
        return f"Alumno[nombre={self.nombre}, apellido={self.apellido}, codigo={self.codigo}, modalidad={self.modalidad}, num_cur={self.num_cur}, n1={self.n1}, n2={self.n2}, n3={self.n3}, n4={self.n4}, n5={self.n5}]"


# Codigo de prueba
a1 = Alumno("Renato", "Sifuentes", 201711069, "Examen", 4, 12, 15, 10, 11)
a2 = Alumno("Cecilia", "Jimenez", 201508111, "Examen", 5, 10, 12, 12, 13, 14.5)
a3 = Alumno("Kim", "Wong", 201605010, "TercioSup", 5, 13, 14, 12, 14, 13)
a4 = Alumno("Juan", "Perez", 201502160, "Nivelacion", 3, 10, 11, 13)
a5 = Alumno("Sandra", "Arana", 201616020, "Beca", 4, 12, 15, 14, 13)

print("Objetos creados")
print("---------------")
print(a1)
print(a2)
print(a3)
print(a4)
print(a5)
print()

lista_alumnos = [a1, a2, a3, a4, a5]

print("Resultados del ciclo")
print("--------------------")

# Insertar un codigo que barra la lista_alumnos y retorne la siguiente impresion:
# Alumno: <Apellido>, <Nombre>   Codigo: <codigo>  Promedio: XX.X   Aprobado: <S|N>
