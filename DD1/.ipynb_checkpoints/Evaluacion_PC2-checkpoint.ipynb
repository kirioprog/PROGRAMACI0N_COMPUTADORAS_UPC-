# %% [markdown]
# # Evaluación - PC2

# %%
import csv

# %% [markdown]
# ## Definción de la clase (4 ptos)
# Escriba una clase que defina un Triangulo valido, con los siguientes detalles:
# - Debe de validar en el momento del instanciamiento si el triangulo es valido
#   (la suma de dos lados debe ser mayor que la suam del tercero).
#   Si el triangulo no es valido, debe de retornar una excepcion de tipo ValueError
#   con el mensaje "El triangulo no es valido". Si el triangulo es valido este
#   instancia.
#
# - El metodo es_escaleno() debe de retornar un booleano indicando si el triangulo
#   es un triangulo escaleno (todos los lados deben ser diferente).
# - El metodo es_iscoceles() debe retornar un booleano indicando si el triangulo
#   es un triangulo iscoceles (dos lados iguales y el tercero diferente).
#
# - El método es_equilatero() debe retornar un booleano indicando si el triangulo
#   es un triangulo equilatero (todos los lados son iguales).
#
# - El método area() retiorna el area del triangulo (formula de Heron)

# %%
import math

class Triangulo:
    
    def __init__(self, ladoA, ladoB, ladoC):
        
        self.ladoA = ladoA
        self.ladoB = ladoB
        self.ladoC = ladoC

        es_valido = (self.ladoA + self.ladoB > self.ladoC) and (self.ladoA + self.ladoC > self.ladoB) and (self.ladoB + self.ladoC > self.ladoA)
        
        if not es_valido:
            raise ValueError("El triangulo no es valido")
      
 # ladoA
    @property             
    def ladoA(self):
        return self._ladoA

    @ladoA.setter         
    def ladoA(self, val):

        if (isinstance(val, (int, float))) and val > 0:
            self._ladoA = val
        else:
            raise TypeError("El ladoA debe ser un 'int' o 'float' positivo")

 #lado B
    @property               #
    def ladoB(self):
        return self._ladoB

    @ladoB.setter           
    def ladoB(self, val):
        if (isinstance(val, (int, float))) and val > 0: #
            self._ladoB = val
        else:
            raise TypeError("El ladoB debe ser un 'int' o 'float' positivo") #

 #lado C
    @property               
    def ladoC(self):
        return self._ladoC

    @ladoC.setter           
    def ladoC(self, val):
        if (isinstance(val, (int, float))) and val > 0: #
            self._ladoC = val
        else:
            raise TypeError("El ladoC debe ser un 'int' o 'float' positivo") #

    #metodos
    
    def es_escaleno(self):
    
        return self.ladoA != self.ladoB and self.ladoA != self.ladoC and self.ladoB != self.ladoC

    def es_isoceles(self):
        
        a, b, c = self.ladoA, self.ladoB, self.ladoC
        return (a == b and a != c) or (a == c and a != b) or (b == c and b != a)

    def es_equilatero(self):
        return self.ladoA == self.ladoB == self.ladoC

    def area(self):
        
        a, b, c = self.ladoA, self.ladoB, self.ladoC
        s = (a + b + c) / 2
        area_calc = math.sqrt(s * (s - a) * (s - b) * (s - c))
        return area_calc

    def __repr__(self):
        return f"Triangulo(ladoA={self.ladoA:2}, ladoB={self.ladoB:2}, ladoC={self.ladoC:2})"

# %%
# CELDA DE PRUEBA DE INSTANCIAMIENTO DE UN TRIANGULO VALIDO (Area: 6u)
t = Triangulo(ladoA=3, ladoB=4, ladoC=5)
print(f"{t} Area: -> {t.area()}u")
# Out:
# Triangulo(ladoA= 3, ladoB= 4, ladoC= 5) Area: -> 6.0u

# %% [markdown]
# # Scripts

# %% [markdown]
# ### Script 1 (2 ptos)
# Escriba un script que guarde en una lista todos los triangulos validos considerando la informacion de lados de un archivo `triangulos.csv`. Muestre el numero de triangulos en la lista.

# %%
import csv  
import math 

class Triangulo:

    
    def __init__(self, ladoA, ladoB, ladoC):

        es_valido = (ladoA + ladoB > ladoC) and (ladoA + ladoC > ladoB) and (ladoB + ladoC > ladoA)
        if not es_valido:
            raise ValueError("El triangulo no es valido (Desigualdad)")
        self.ladoA = ladoA
        self.ladoB = ladoB
        self.ladoC = ladoC

    def es_escaleno(self):
        return self.ladoA != self.ladoB and self.ladoA != self.ladoC and self.ladoB != self.ladoC
    def es_isoceles(self):
        a, b, c = self.ladoA, self.ladoB, self.ladoC
        return (a == b and a != c) or (a == c and a != b) or (b == c and b != a)

    def es_equilatero(self):
        return self.ladoA == self.ladoB == self.ladoC

    def area(self):
        s = (self.ladoA + self.ladoB + self.ladoC) / 2
        return math.sqrt(s * (s - a) * (s - b) * (s - c))

    def __repr__(self):
        return f"Triangulo(ladoA={self.ladoA:2}, ladoB={self.ladoB:2}, ladoC={self.ladoC:2})"


lista_triangulos_validos = []
nombre_archivo = 'triangulos.csv'

try:
    with open(nombre_archivo, mode='r', encoding='utf-8') as archivo:
    
        lector_csv = csv.DictReader(archivo)
        for fila_dict in lector_csv:
            try:
                # 1. Convertir a 'int' (confiando en los datos)
                lado_a_csv = int(fila_dict['LADOA'])
                lado_b_csv = int(fila_dict['LADOB'])
                lado_c_csv = int(fila_dict['LADOC'])

                nuevo_triangulo = Triangulo(lado_a_csv, lado_b_csv, lado_c_csv)
                
                lista_triangulos_validos.append(nuevo_triangulo)
                
            except:
                pass
            
except:
    print(f"Error fatal: No se encontró el archivo '{nombre_archivo}'")

print(f"Numero de triangulos validos: {len(lista_triangulos_validos)}")

# %%
<NO EJECUTE ESTA CELDA, ES PARA VALIDACION DE RESULTADOS>
# Out:
# Numero de triangulos validos: 51

# %% [markdown]
# ### Script 2 (2 ptos)
# Escriba un script que imprima las tuplas con los tres lados que no logran formar un triangulo, considerando la informacion de lados de un archivo `triangulos.csv`. Muestre el numero de triangulos invalidos.

# %%
import csv

lista_invalidos = []
nombre_archivo = 'triangulos.csv'

try:
    with open(nombre_archivo, mode='r', encoding='utf-8') as archivo:
        lector_csv = csv.DictReader(archivo)
        for fila_dict in lector_csv:
            try:
                a = float(fila_dict['LADOA'])
                b = float(fila_dict['LADOB'])
                c = float(fila_dict['LADOC'])
                es_valido = (a > 0 and b > 0 and c > 0) and (a + b > c) and (a + c > b) and (b + c > a)
                if not es_valido:
                    lista_invalidos.append((a, b, c))
            except :
                a_str = fila_dict.get('LADOA', '?')
                b_str = fila_dict.get('LADOB', '?')
                c_str = fila_dict.get('LADOC', '?')
                lista_invalidos.append((a_str, b_str, c_str))

except FileNotFoundError:
    print(f"Error fatal: No se encontró el archivo '{nombre_archivo}'")
except Exception as e:
    print(f"Ocurrió un error inesperado: {e}")

for tupla in lista_invalidos:
    print(f"Triangulo Invalido: {tupla}")

print(f"\nNum Triangulos Invalidos: {len(lista_invalidos)}")

# %%
<NO EJECUTE ESTA CELDA, ES PARA VALIDACION DE RESULTADOS>
# Out:
# Triangulo Invalido: (-2, 4, 12)
# Triangulo Invalido: (0, 6, 3)
# Triangulo Invalido: (4, 4, 9)
# Triangulo Invalido: (6, 10, 4)
# Triangulo Invalido: (12, 5, 7)
# Triangulo Invalido: (2, 2, 5)
# Triangulo Invalido: (1, 1, 3)
#
# Num Triangulos Invalidos: 7

# %% [markdown]
# ### Script 3 (2 ptos)
# Escriba un script que imprima un listado de los triangulos escalenos en la lista de triangulos previamente generado. Muestre el número de triangulos impresos.

# %%
import csv
import math

class Triangulo:
    
    def __init__(self, ladoA, ladoB, ladoC):
        
        es_valido = (ladoA + ladoB > ladoC) and (ladoA + ladoC > ladoB) and (ladoB + ladoC > ladoA) and (ladoA > 0 and ladoB > 0 and ladoC > 0)
        
        if not es_valido:
            raise ValueError("El triangulo no es valido")
        
        self.ladoA = ladoA
        self.ladoB = ladoB
        self.ladoC = ladoC

    def es_escaleno(self):
        return self.ladoA != self.ladoB and self.ladoA != self.ladoC and self.ladoB != self.ladoC

    def es_isoceles(self):
        a, b, c = self.ladoA, self.ladoB, self.ladoC
        return (a == b and a != c) or (a == c and a != b) or (b == c and b != a)

    def es_equilatero(self):
        return self.ladoA == self.ladoB == self.ladoC

    def area(self):
        s = (self.ladoA + self.ladoB + self.ladoC) / 2
        return math.sqrt(s * (s - self.ladoA) * (s - self.ladoB) * (s - self.ladoC))

    def __repr__(self):
        return f"Triangulo(ladoA={self.ladoA:4}, ladoB={self.ladoB:4}, ladoC={self.ladoC:2})"

lista_triangulos_validos = []
nombre_archivo = 'triangulos.csv'

try:
    with open(nombre_archivo, mode='r', encoding='utf-8') as archivo:
        
        lector_csv = csv.DictReader(archivo)
        
        for fila_dict in lector_csv:
            
            try:
                lado_a_csv = float(fila_dict['LADOA'])
                lado_b_csv = float(fila_dict['LADOB'])
                lado_c_csv = float(fila_dict['LADOC'])
                
                nuevo_triangulo = Triangulo(lado_a_csv, lado_b_csv, lado_c_csv)
                
                lista_triangulos_validos.append(nuevo_triangulo)
                
            except (ValueError, TypeError, KeyError):
                pass
            
except FileNotFoundError:
    print(f"Error fatal: No se encontró el archivo '{nombre_archivo}'")
except Exception as e:
    print(f"Ocurrió un error inesperado: {e}")

contador_escalenos = 0
for t in lista_triangulos_validos:
    if t.es_escaleno():
        print(t)
        contador_escalenos += 1

print(f"\nNum Triangulos Escalenos: {contador_escalenos}")

# %%
<NO EJECUTE ESTA CELDA, ES PARA VALIDACION DE RESULTADOS>
# Out:
# Triangulo(ladoA= 9, ladoB=10, ladoC=11)
# Triangulo(ladoA= 5, ladoB= 9, ladoC=10)
# Triangulo(ladoA=10, ladoB=12, ladoC=13)
# Triangulo(ladoA=13, ladoB=15, ladoC=16)
# Triangulo(ladoA=11, ladoB=13, ladoC=14)
# Triangulo(ladoA= 6, ladoB= 7, ladoC= 8)
# Triangulo(ladoA=20, ladoB=22, ladoC=23)
# Triangulo(ladoA= 4, ladoB= 5, ladoC= 6)
# Triangulo(ladoA=12, ladoB=14, ladoC=15)
# Triangulo(ladoA=16, ladoB=18, ladoC=19)
# Triangulo(ladoA=14, ladoB=16, ladoC=17)
# Triangulo(ladoA=17, ladoB=19, ladoC=20)
# Triangulo(ladoA=15, ladoB=17, ladoC=18)
# Triangulo(ladoA= 8, ladoB=10, ladoC=12)
# Triangulo(ladoA=19, ladoB=21, ladoC=22)
# Triangulo(ladoA=22, ladoB=24, ladoC=25)
# Triangulo(ladoA=18, ladoB=20, ladoC=21)
# Triangulo(ladoA=23, ladoB=25, ladoC=26)
# Triangulo(ladoA= 7, ladoB= 8, ladoC=10)
# Triangulo(ladoA=17, ladoB=19, ladoC=10)
#
# Num Triangulos Escalenos: 20

# %% [markdown]
# ### Script 4 (2 ptos)
# Escriba un script que imprima un listado de los triangulos isoceles en la lista de triangulos previamente generado. Muestre el número de triangulos impresos.

# %%
import csv
import math

class Triangulo:
    
    def __init__(self, ladoA, ladoB, ladoC):
        
        es_valido = (ladoA + ladoB > ladoC) and (ladoA + ladoC > ladoB) and (ladoB + ladoC > ladoA) and (ladoA > 0 and ladoB > 0 and ladoC > 0)
        
        if not es_valido:
            raise ValueError("El triangulo no es valido")
        
        self.ladoA = ladoA
        self.ladoB = ladoB
        self.ladoC = ladoC

    def es_escaleno(self):
        return self.ladoA != self.ladoB and self.ladoA != self.ladoC and self.ladoB != self.ladoC

    def es_isoceles(self):
        a, b, c = self.ladoA, self.ladoB, self.ladoC
        return (a == b and a != c) or (a == c and a != b) or (b == c and b != a)

    def es_equilatero(self):
        return self.ladoA == self.ladoB == self.ladoC

    def area(self):
        s = (self.ladoA + self.ladoB + self.ladoC) / 2
        return math.sqrt(s * (s - self.ladoA) * (s - self.ladoB) * (s - self.ladoC))

    def __repr__(self):
        return f"Triangulo(ladoA={self.ladoA:2}, ladoB={self.ladoB:2}, ladoC={self.ladoC:2})"

lista_triangulos_validos = []
nombre_archivo = 'triangulos.csv'

try:
    with open(nombre_archivo, mode='r', encoding='utf-8') as archivo:
        
        lector_csv = csv.DictReader(archivo)
        
        for fila_dict in lector_csv:
            
            try:
                lado_a_csv = float(fila_dict['LADOA'])
                lado_b_csv = float(fila_dict['LADOB'])
                lado_c_csv = float(fila_dict['LADOC'])
                
                nuevo_triangulo = Triangulo(lado_a_csv, lado_b_csv, lado_c_csv)
                
                lista_triangulos_validos.append(nuevo_triangulo)
                
            except (ValueError, TypeError, KeyError):
                pass
            
except FileNotFoundError:
    print(f"Error fatal: No se encontró el archivo '{nombre_archivo}'")
except Exception as e:
    print(f"Ocurrió un error inesperado: {e}")

contador_isoceles = 0
for t in lista_triangulos_validos:
    if t.es_isoceles():
        print(t)
        contador_isoceles += 1

print(f"\nNum Triangulos Isoceles: {contador_isoceles}")

# %%
<NO EJECUTE ESTA CELDA, ES PARA VALIDACION DE RESULTADOS>
# Out:
# Triangulo(ladoA= 7, ladoB= 7, ladoC= 5)
# Triangulo(ladoA=10, ladoB=10, ladoC= 8)
# Triangulo(ladoA=15, ladoB=15, ladoC=10)
# Triangulo(ladoA=14, ladoB=14, ladoC= 9)
# Triangulo(ladoA=13, ladoB=13, ladoC= 8)
# Triangulo(ladoA=16, ladoB=16, ladoC=11)
# Triangulo(ladoA= 5, ladoB= 5, ladoC= 3)
# Triangulo(ladoA=20, ladoB=20, ladoC=15)
# Triangulo(ladoA= 6, ladoB= 6, ladoC= 4)
# Triangulo(ladoA=17, ladoB=17, ladoC=12)
# Triangulo(ladoA=11, ladoB=11, ladoC= 6)
# Triangulo(ladoA= 9, ladoB= 9, ladoC= 5)
# Triangulo(ladoA=18, ladoB=18, ladoC=13)
# Triangulo(ladoA=24, ladoB=24, ladoC=19)
# Triangulo(ladoA=22, ladoB=22, ladoC=17)
# Triangulo(ladoA=19, ladoB=19, ladoC=14)
# Triangulo(ladoA= 8, ladoB= 8, ladoC= 5)
# Triangulo(ladoA=23, ladoB=23, ladoC=18)
#
# Num Triangulos Isoceles: 18

# %% [markdown]
# ### Script 5 (2 ptos)
# Escriba un script que imprima un listado de los triangulos equilateros en la lista de triangulos previamente generado. Muestre el número de triangulos impresos.

# %%
import csv
import math

class Triangulo:
    
    def __init__(self, ladoA, ladoB, ladoC):
        
        es_valido = (ladoA + ladoB > ladoC) and (ladoA + ladoC > ladoB) and (ladoB + ladoC > ladoA) and (ladoA > 0 and ladoB > 0 and ladoC > 0)
        
        if not es_valido:
            raise ValueError("El triangulo no es valido")
        
        self.ladoA = ladoA
        self.ladoB = ladoB
        self.ladoC = ladoC

    def es_escaleno(self):
        return self.ladoA != self.ladoB and self.ladoA != self.ladoC and self.ladoB != self.ladoC

    def es_isoceles(self):
        a, b, c = self.ladoA, self.ladoB, self.ladoC
        return (a == b and a != c) or (a == c and a != b) or (b == c and b != a)

    def es_equilatero(self):
        return self.ladoA == self.ladoB == self.ladoC

    def area(self):
        s = (self.ladoA + self.ladoB + self.ladoC) / 2
        return math.sqrt(s * (s - self.ladoA) * (s - self.ladoB) * (s - self.ladoC))

    def __repr__(self):
        # Ajustado para que coincida con tu formato de salida
        return f"Triangulo(ladoA={self.ladoA}, ladoB={self.ladoB}, ladoC={self.ladoC})"

lista_triangulos_validos = []
nombre_archivo = 'triangulos.csv'

try:
    with open(nombre_archivo, mode='r', encoding='utf-8') as archivo:
        
        lector_csv = csv.DictReader(archivo)
        
        for fila_dict in lector_csv:
            
            try:
                lado_a_csv = float(fila_dict['LADOA'])
                lado_b_csv = float(fila_dict['LADOB'])
                lado_c_csv = float(fila_dict['LADOC'])
                
                nuevo_triangulo = Triangulo(lado_a_csv, lado_b_csv, lado_c_csv)
                
                lista_triangulos_validos.append(nuevo_triangulo)
                
            except (ValueError, TypeError, KeyError):
                pass
            
except FileNotFoundError:
    print(f"Error fatal: No se encontró el archivo '{nombre_archivo}'")
except Exception as e:
    print(f"Ocurrió un error inesperado: {e}")

contador_equilateros = 0
for t in lista_triangulos_validos:
    if t.es_equilatero():
        print(t)
        contador_equilateros += 1

print(f"\nNum Triangulos Equilateros: {contador_equilateros}")

# %%
<NO EJECUTE ESTA CELDA, ES PARA VALIDACION DE RESULTADOS>
# Out:
# Triangulo(ladoA=12, ladoB=12, ladoC=12)
# Triangulo(ladoA=10, ladoB=10, ladoC=10)
# Triangulo(ladoA=21, ladoB=21, ladoC=21)
# Triangulo(ladoA=18, ladoB=18, ladoC=18)
# Triangulo(ladoA= 8, ladoB= 8, ladoC= 8)
# Triangulo(ladoA=20, ladoB=20, ladoC=20)
# Triangulo(ladoA= 3, ladoB= 3, ladoC= 3)
# Triangulo(ladoA= 6, ladoB= 6, ladoC= 6)
# Triangulo(ladoA=13, ladoB=13, ladoC=13)
# Triangulo(ladoA= 5, ladoB= 5, ladoC= 5)
# Triangulo(ladoA=22, ladoB=22, ladoC=22)
# Triangulo(ladoA=14, ladoB=14, ladoC=14)
# Triangulo(ladoA=11, ladoB=11, ladoC=11)
#
# Num Triangulos Equilateros: 13

# %% [markdown]
# ### Script 6 (3 ptos)
# Esciba un script que imprima un listado de los trianglos, junto con el indice posicional de cada triangulo en la lista previamente generada, asi como el area de cada triangulo. Muestre el numero del area promedio de todos los triangulos impresos.

# %%
import csv
import math

class Triangulo:
    
    def __init__(self, ladoA, ladoB, ladoC):
        
        es_valido = (ladoA > 0 and ladoB > 0 and ladoC > 0) and (ladoA + ladoB > ladoC) and (ladoA + ladoC > ladoB) and (ladoB + ladoC > ladoA)
        
        if not es_valido:
            raise ValueError("El triangulo no es valido")
        
        self.ladoA = ladoA
        self.ladoB = ladoB
        self.ladoC = ladoC

    def es_escaleno(self):
        return self.ladoA != self.ladoB and self.ladoA != self.ladoC and self.ladoB != self.ladoC

    def es_isoceles(self):
        a, b, c = self.ladoA, self.ladoB, self.ladoC
        return (a == b and a != c) or (a == c and a != b) or (b == c and b != a)

    def es_equilatero(self):
        return self.ladoA == self.ladoB == self.ladoC

    def area(self):
        s = (self.ladoA + self.ladoB + self.ladoC) / 2
        return math.sqrt(s * (s - self.ladoA) * (s - self.ladoB) * (s - self.ladoC))

    def __repr__(self):
        return f"Triangulo(ladoA={self.ladoA}, ladoB={self.ladoB}, ladoC={self.ladoC})"

lista_triangulos_validos = []
nombre_archivo = 'triangulos.csv'
total_area = 0.0

try:
    with open(nombre_archivo, mode='r', encoding='utf-8') as archivo:
        
        lector_csv = csv.DictReader(archivo)
        
        for fila_dict in lector_csv:
            
            try:
                lado_a_csv = float(fila_dict['LADOA'])
                lado_b_csv = float(fila_dict['LADOB'])
                lado_c_csv = float(fila_dict['LADOC'])
                
                nuevo_triangulo = Triangulo(lado_a_csv, lado_b_csv, lado_c_csv)
                
                lista_triangulos_validos.append(nuevo_triangulo)
                
            except (ValueError, TypeError, KeyError):
                pass
            
except FileNotFoundError:
    print(f"Error fatal: No se encontró el archivo '{nombre_archivo}'")
except Exception as e:
    print(f"Ocurrió un error inesperado: {e}")

if len(lista_triangulos_validos) > 0:
    for idx, t in enumerate(lista_triangulos_validos):
        area_actual = t.area()
        total_area += area_actual
        print(f"{idx}: {t} | Area: {area_actual:.2f}u")
    
    area_promedio = total_area / len(lista_triangulos_validos)
    print(f"\nArea promedio de los triangulos: {area_promedio:.2f}u")
else:
    print("No se encontraron triangulos validos.")

# %%
<NO EJECUTE ESTA CELDA, ES PARA VALIDACION DE RESULTADOS>
# Out:
#  0: Triangulo(ladoA= 7, ladoB= 7, ladoC= 5) | Area: 16.35u
#  1: Triangulo(ladoA= 9, ladoB=10, ladoC=11) | Area: 42.43u
#  2: Triangulo(ladoA=10, ladoB=10, ladoC= 8) | Area: 36.66u
#  3: Triangulo(ladoA=15, ladoB=15, ladoC=10) | Area: 70.71u
#  4: Triangulo(ladoA= 5, ladoB= 9, ladoC=10) | Area: 22.45u
#  5: Triangulo(ladoA=14, ladoB=14, ladoC= 9) | Area: 59.66u
#  6: Triangulo(ladoA=10, ladoB=12, ladoC=13) | Area: 57.00u
#  7: Triangulo(ladoA=13, ladoB=15, ladoC=16) | Area: 91.19u
#  8: Triangulo(ladoA=12, ladoB=12, ladoC=12) | Area: 62.35u
#  9: Triangulo(ladoA=11, ladoB=13, ladoC=14) | Area: 67.53u
# 10: Triangulo(ladoA=10, ladoB=10, ladoC=10) | Area: 43.30u
# 11: Triangulo(ladoA=13, ladoB=13, ladoC= 8) | Area: 49.48u
# 12: Triangulo(ladoA= 6, ladoB= 7, ladoC= 8) | Area: 20.33u
# 13: Triangulo(ladoA=21, ladoB=21, ladoC=21) | Area: 190.96u
# 14: Triangulo(ladoA=20, ladoB=22, ladoC=23) | Area: 201.30u
# 15: Triangulo(ladoA= 4, ladoB= 5, ladoC= 6) | Area: 9.92u
# 16: Triangulo(ladoA=12, ladoB=14, ladoC=15) | Area: 78.93u
# 17: Triangulo(ladoA=16, ladoB=16, ladoC=11) | Area: 82.64u
# 18: Triangulo(ladoA=16, ladoB=18, ladoC=19) | Area: 133.19u
# 19: Triangulo(ladoA= 5, ladoB= 5, ladoC= 3) | Area: 7.15u
# 20: Triangulo(ladoA=20, ladoB=20, ladoC=15) | Area: 139.05u
# 21: Triangulo(ladoA=14, ladoB=16, ladoC=17) | Area: 104.32u
# 22: Triangulo(ladoA=18, ladoB=18, ladoC=18) | Area: 140.30u
# 23: Triangulo(ladoA=17, ladoB=19, ladoC=20) | Area: 148.92u
# 24: Triangulo(ladoA= 6, ladoB= 6, ladoC= 4) | Area: 11.31u
# 25: Triangulo(ladoA=15, ladoB=17, ladoC=18) | Area: 118.32u
# 26: Triangulo(ladoA= 8, ladoB=10, ladoC=12) | Area: 39.69u
# 27: Triangulo(ladoA=19, ladoB=21, ladoC=22) | Area: 182.98u
# 28: Triangulo(ladoA= 8, ladoB= 8, ladoC= 8) | Area: 27.71u
# 29: Triangulo(ladoA=17, ladoB=17, ladoC=12) | Area: 95.44u
# 30: Triangulo(ladoA=11, ladoB=11, ladoC= 6) | Area: 31.75u
# 31: Triangulo(ladoA=20, ladoB=20, ladoC=20) | Area: 173.21u
# 32: Triangulo(ladoA=22, ladoB=24, ladoC=25) | Area: 240.56u
# 33: Triangulo(ladoA=18, ladoB=20, ladoC=21) | Area: 165.51u
# 34: Triangulo(ladoA=23, ladoB=25, ladoC=26) | Area: 261.49u
# 35: Triangulo(ladoA= 9, ladoB= 9, ladoC= 5) | Area: 21.61u
# 36: Triangulo(ladoA=18, ladoB=18, ladoC=13) | Area: 109.11u
# 37: Triangulo(ladoA=24, ladoB=24, ladoC=19) | Area: 209.38u
# 38: Triangulo(ladoA= 7, ladoB= 8, ladoC=10) | Area: 27.81u
# 39: Triangulo(ladoA=22, ladoB=22, ladoC=17) | Area: 172.48u
# 40: Triangulo(ladoA=19, ladoB=19, ladoC=14) | Area: 123.64u
# 41: Triangulo(ladoA= 3, ladoB= 3, ladoC= 3) | Area: 3.90u
# 42: Triangulo(ladoA= 6, ladoB= 6, ladoC= 6) | Area: 15.59u
# 43: Triangulo(ladoA= 8, ladoB= 8, ladoC= 5) | Area: 19.00u
# 44: Triangulo(ladoA=17, ladoB=19, ladoC=10) | Area: 84.71u
# 45: Triangulo(ladoA=13, ladoB=13, ladoC=13) | Area: 73.18u
# 46: Triangulo(ladoA= 5, ladoB= 5, ladoC= 5) | Area: 10.83u
# 47: Triangulo(ladoA=23, ladoB=23, ladoC=18) | Area: 190.49u
# 48: Triangulo(ladoA=22, ladoB=22, ladoC=22) | Area: 209.58u
# 49: Triangulo(ladoA=14, ladoB=14, ladoC=14) | Area: 84.87u
# 50: Triangulo(ladoA=11, ladoB=11, ladoC=11) | Area: 52.39u
#
# Area promedio de los triangulos: 90.84u

# %% [markdown]
# ### Script 7 (3 ptos)
# Muestre la posicion del triangulo con menor y mayor area, donde se muestre el indice posicional de cada triangulo y el area correspondiente

# %%
import csv
import math

class Triangulo:
    
    def __init__(self, ladoA, ladoB, ladoC):
        
        es_valido = (ladoA > 0 and ladoB > 0 and ladoC > 0) and (ladoA + ladoB > ladoC) and (ladoA + ladoC > ladoB) and (ladoB + ladoC > ladoA)
        
        if not es_valido:
            raise ValueError("El triangulo no es valido")
        
        self.ladoA = ladoA
        self.ladoB = ladoB
        self.ladoC = ladoC

    def es_escaleno(self):
        return self.ladoA != self.ladoB and self.ladoA != self.ladoC and self.ladoB != self.ladoC

    def es_isoceles(self):
        a, b, c = self.ladoA, self.ladoB, self.ladoC
        return (a == b and a != c) or (a == c and a != b) or (b == c and b != a)

    def es_equilatero(self):
        return self.ladoA == self.ladoB == self.ladoC

    def area(self):
        s = (self.ladoA + self.ladoB + self.ladoC) / 2
        return math.sqrt(s * (s - self.ladoA) * (s - self.ladoB) * (s - self.ladoC))

    def __repr__(self):
        return f"Triangulo(ladoA={self.ladoA}, ladoB={self.ladoB}, ladoC={self.ladoC})"

lista_triangulos_validos = []
nombre_archivo = 'triangulos.csv'

try:
    with open(nombre_archivo, mode='r', encoding='utf-8') as archivo:
        
        lector_csv = csv.DictReader(archivo)
        
        for fila_dict in lector_csv:
            
            try:
                lado_a_csv = float(fila_dict['LADOA'])
                lado_b_csv = float(fila_dict['LADOB'])
                lado_c_csv = float(fila_dict['LADOC'])
                
                nuevo_triangulo = Triangulo(lado_a_csv, lado_b_csv, lado_c_csv)
                
                lista_triangulos_validos.append(nuevo_triangulo)
                
            except (ValueError, TypeError, KeyError):
                pass
            
except FileNotFoundError:
    print(f"Error fatal: No se encontró el archivo '{nombre_archivo}'")
except Exception as e:
    print(f"Ocurrió un error inesperado: {e}")

if len(lista_triangulos_validos) > 0:
    area_min = math.inf
    idx_min = -1
    area_max = 0.0
    idx_max = -1

    for idx, t in enumerate(lista_triangulos_validos):
        area_actual = t.area()
        
        if area_actual < area_min:
            area_min = area_actual
            idx_min = idx
            
        if area_actual > area_max:
            area_max = area_actual
            idx_max = idx
            
    print(f"T Menor: {idx_min} -> Area: {area_min:.2f}u")
    print(f"T Mayor: {idx_max} -> Area: {area_max:.2f}u")
else:
    print("No se encontraron triangulos validos.")

# %%
<NO EJECUTE ESTA CELDA, ES PARA VALIDACION DE RESULTADOS>
# Out:
# T Menor: 41 -> Area: 3.90u
# T Mayor: 34 -> Area 261.49u
